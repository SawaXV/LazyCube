# %% [markdown]
# # LazyCube training script
# > **DO NOT SHARE THIS WITH ANYONE ELSE, IT HAS PRIVATE API KEYS IN IT!**

# %% [markdown]
# ## Repo + dependency init

# %%
# %cd /content
# !git clone https://gitlab-ci-token:glpat-qD8odpMKq7TXY66Kwu9n@projects.cs.nott.ac.uk/comp2002/2022-2023/team43_project.git
# %cd /content/team43_project/deep-learning
# !git checkout deep-learning
# Out:
# /content
# Cloning into 'team43_project'...
# remote: Enumerating objects: 5825, done.
# remote: Counting objects: 100% (5749/5749), done.
# remote: Compressing objects: 100% (2090/2090), done.
# remote: Total 5825 (delta 2684), reused 5484 (delta 2484), pack-reused 76
# Receiving objects: 100% (5825/5825), 111.78 MiB | 11.15 MiB/s, done.
# Resolving deltas: 100% (2701/2701), done.
# /content/team43_project/deep-learning
# Branch 'deep-learning' set up to track remote branch 'deep-learning' from 'origin'.
# Switched to a new branch 'deep-learning'

# %%
# !pip install roboflow==0.2.29
# !pip install python-dotenv
# !pip uninstall -y tensorflow && pip install -q tensorflow==2.8.0
# !pip install tflite-model-maker
# !pip install tflite-support
# !pip install pycocotools
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.0/49.0 KB 5.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 KB 9.0 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 KB 8.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 KB 7.4 MB/s eta 0:00:00
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9676 sha256=bdacf3126d8ba84da439b1b10ccdafb63081130a727f51a70e4f2713e2444ce2
#   Stored in directory: /root/.cache/pip/wheels/04/5f/3e/46cc37c5d698415694d83f607f833f83f0149e49b3af9d0f38
# Successfully built wget
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.9
#     Uninstalling pyparsing-3.0.9:
#       Successfully uninstalled pyparsing-3.0.9
#   Attempting uninstall: idna
#     Found existing installation: idna 3.4
# ...

# %%
# !touch .env
# !echo "ROBOFLOW_API=7o4XB3u4LDkeMdHuWb0r" > .env

# %% [markdown]
# ## Train det0 model
# Train det0 model using efficientdet_lite0, a model ready for mobile deployment

# %%
# !python train.py --epochs 250 --batch-size 64
# Out:
# Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.9.0 and strictly below 2.12.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.8.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
# loading Roboflow workspace...
# loading Roboflow project...
# Exporting format voc in progress : 85.0%
# Version export complete for voc format
# ...
# Extracting Dataset Version Zip to LazyCube-16 in voc:: 100% 2873/2873 [00:00<00:00, 7103.75it/s]
# ...

# %%
# %cd /content/team43_project/deep-learning
# !mkdir TFL/Models/latest
# !cp -f lazycubedet0.tflite TFL/Models/latest/lazycubedet0.tflite
# !git pull
# !git config user.email "project10031_bot@noreply.gitlab.com"
# !git config user.name "gradient_token"
# !git add TFL/Models/latest/lazycubedet0.tflite
# !git commit -m "Update TFL det0 model"
# !git push origin deep-learning
# Out:
# /content/team43_project/deep-learning
# mkdir: cannot create directory ‘TFL/Models/latest’: File exists
# remote: Enumerating objects: 322, done.
# remote: Counting objects: 100% (269/269), done.
# remote: Compressing objects: 100% (112/112), done.
# remote: Total 152 (delta 84), reused 25 (delta 8), pack-reused 0
# Receiving objects: 100% (152/152), 18.58 KiB | 464.00 KiB/s, done.
# Resolving deltas: 100% (84/84), completed with 30 local objects.
# From https://projects.cs.nott.ac.uk/comp2002/2022-2023/team43_project
#    7df884d..47c3a53  android-app        -> origin/android-app
#  * [new branch]      l-ab-failure-recovery-tuning -> origin/l-ab-failure-recovery-tuning
#    c29c96b..df63e50  main               -> origin/main
#    0db9da9..5d7ccc5  u-mb-update-navbar -> origin/u-mb-update-navbar
# Already up to date.
# [deep-learning e3f2367] Update TFL det0 model
#  1 file changed, 0 insertions(+), 0 deletions(-)
# Enumerating objects: 13, done.
# ...

# %% [markdown]
# ## Train Detx model
# Train a more complex model using the efficientdet_lite3 model

# %%
# !python train.py --spec efficientdet_lite3 --model-name lazycubedetx.tflite
# Out:
# Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.9.0 and strictly below 2.12.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.8.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to LazyCube-12 in voc:: 100% 2071/2071 [00:00<00:00, 4442.51it/s]
# 2023-02-22 11:48:29.060063: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# ...

# %%
# %cd /content/team43_project/deep-learning
# !mkdir TFL/Models/latest
# !cp -f lazycubedetx.tflite TFL/Models/latest/lazycubedetx.tflite
# !git pull
# !git config user.email "project10031_bot@noreply.gitlab.com"
# !git config user.name "gradient_token"
# !git add TFL/Models/latest/lazycubedetx.tflite
# !git commit -m "Update TFL detx model"
# !git push origin deep-learning
